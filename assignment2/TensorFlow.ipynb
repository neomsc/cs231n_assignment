# %% [markdown]
# ## What's this TensorFlow business?
#
# You've written a lot of code in this assignment to provide a whole host of neural network functionality. Dropout, Batch Norm, and 2D convolutions are some of the workhorses of deep learning in computer vision. You've also worked hard to make your code efficient and vectorized.
#
# For the last part of this assignment, though, we're going to leave behind your beautiful codebase and instead migrate to one of two popular deep learning frameworks: in this instance, TensorFlow (or PyTorch, if you switch over to that notebook)
#
# #### What is it?
# TensorFlow is a system for executing computational graphs over Tensor objects, with native support for performing backpropogation for its Variables. In it, we work with Tensors which are n-dimensional arrays analogous to the numpy ndarray.
#
# #### Why?
#
# * Our code will now run on GPUs! Much faster training. Writing your own modules to run on GPUs is beyond the scope of this class, unfortunately.
# * We want you to be ready to use one of these frameworks for your project so you can experiment more efficiently than if you were writing every feature you want to use by hand.
# * We want you to stand on the shoulders of giants! TensorFlow and PyTorch are both excellent frameworks that will make your lives a lot easier, and now that you understand their guts, you are free to use them :)
# * We want you to be exposed to the sort of deep learning code you might run into in academia or industry.

# %% [markdown]
# ## How will I learn TensorFlow?
#
# TensorFlow has many excellent tutorials available, including those from [Google themselves](https://www.tensorflow.org/get_started/get_started).
#
# Otherwise, this notebook will walk you through much of what you need to do to train models in TensorFlow. See the end of the notebook for some links to helpful tutorials if you want to learn more or need further clarification on topics that aren't fully explained here.

# %% [markdown]
# ## Load Datasets

# %%
import tensorflow as tf
import numpy as np
import math
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\me\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=10000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %% [markdown]
# ## Example Model
#
# ### Some useful utilities
#
# . Remember that our image data is initially N x H x W x C, where:
# * N is the number of datapoints
# * H is the height of each image in pixels
# * W is the height of each image in pixels
# * C is the number of channels (usually 3: R, G, B)
#
# This is the right way to represent the data when we are doing something like a 2D convolution, which needs spatial understanding of where the pixels are relative to each other. When we input image data into fully connected affine layers, however, we want each data example to be represented by a single vector -- it's no longer useful to segregate the different channels, rows, and columns of the data.

# %% [markdown]
# ### The example model itself
#
# The first step to training your own model is defining its architecture.
#
# Here's an example of a convolutional neural network defined in TensorFlow -- try to understand what each line is doing, remembering that each layer is composed upon the previous layer. We haven't trained anything yet - that'll come next - for now, we want you to understand how everything gets set up.
#
# In that example, you see 2D convolutional layers (Conv2d), ReLU activations, and fully-connected layers (Linear). You also see the Hinge loss function, and the Adam optimizer being used.
#
# Make sure you understand why the parameters of the Linear layer are 5408 and 10.
#
# ### TensorFlow Details
# In TensorFlow, much like in our previous notebooks, we'll first specifically initialize our variables, and then our network model.

# %%
# clear old variables
tf.reset_default_graph()

# setup input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

def simple_model(X,y):
    # define our weights (e.g. init_two_layer_convnet)
    
    # setup variables
    Wconv1 = tf.get_variable("Wconv1", shape=[7, 7, 3, 32])
    bconv1 = tf.get_variable("bconv1", shape=[32])
    W1 = tf.get_variable("W1", shape=[1152, 1024])
    b1 = tf.get_variable("b1", shape=[1024])
    W2 = tf.get_variable("W2", shape=[1024, 10])
    b2 = tf.get_variable("b2", shape=[10])

    # define our graph (e.g. two_layer_convnet)
    a1 = tf.nn.conv2d(X, Wconv1, strides=[1,2,2,1], padding='VALID') + bconv1
    h1 = tf.nn.relu(a1)
    
    batch1 = tf.layers.batch_normalization(h1)
    pool1 = tf.layers.max_pooling2d(batch1,2,2)
    h1_flat = tf.reshape(pool1,[-1,1152])
    #h1_flat = tf.reshape(h1,[-1,5408])
    
    a2 =tf.matmul(h1_flat,W1) + b1
    h2 = tf.nn.relu(a2)
    y_out = tf.matmul(h2,W2) + b2
    return y_out

y_out = simple_model(X,y)

# define our loss
total_loss = tf.losses.hinge_loss(tf.one_hot(y,10),logits=y_out)
mean_loss = tf.reduce_mean(total_loss)

# define our optimizer
optimizer = tf.train.AdamOptimizer(5e-4) # select optimizer and set learning rate
train_step = optimizer.minimize(mean_loss)

# %% [markdown]
# TensorFlow supports many other layer types, loss functions, and optimizers - you will experiment with these next. Here's the official API documentation for these (if any of the parameters used above were unclear, this resource will also be helpful).
#
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers
# * BatchNorm: https://www.tensorflow.org/api_docs/python/tf/layers/batch_normalization

# %% [markdown]
# ### Training the model on one epoch
# While we have defined a graph of operations above, in order to execute TensorFlow Graphs, by feeding them input data and computing the results, we first need to create a `tf.Session` object. A session encapsulates the control and state of the TensorFlow runtime. For more information, see the TensorFlow [Getting started](https://www.tensorflow.org/get_started/get_started) guide.
#
# Optionally we can also specify a device context such as `/cpu:0` or `/gpu:0`. For documentation on this behavior see [this TensorFlow guide](https://www.tensorflow.org/tutorials/using_gpu)
#
# You should see a validation loss of around 0.4 to 0.6 and an accuracy of 0.30 to 0.35 below

# %%
def run_model(session, predict, loss_val, Xd, yd,Xval,yval,
              epochs=1, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    correct_prediction = tf.equal(tf.argmax(predict,1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # shuffle indicies

    training_now = training is not None
    
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [mean_loss,correct_prediction,accuracy]
    if training_now:
        variables[-1] = training
    
    # counter 
    iter_cnt = 0
    corrs = []
    corrs2 = []
    for e in range(epochs):
        # keep track of losses and accuracy
        train_indicies = np.arange(Xd.shape[0])
        np.random.shuffle(train_indicies)
        correct = 0
        losses = []
        # make sure we iterate over the dataset once
        for i in range(int(math.ceil(Xd.shape[0]/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%Xd.shape[0]
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            # create a feed dictionary for this batch
            feed_dict = {X: Xd[idx,:],
                         y: yd[idx],
                         is_training: training_now }
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step
            loss, corr, _ = session.run(variables,feed_dict=feed_dict)
            
            # aggregate performance stats
            losses.append(loss*actual_batch_size)
            temp = np.sum(corr)
            correct += temp
            # print every now and then
            if training_now and (iter_cnt % print_every) == 0:
                print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"\
                      .format(iter_cnt,loss,np.sum(corr)/actual_batch_size))
            iter_cnt += 1
        total_correct = correct/Xd.shape[0]
        corrs.append(total_correct)
        total_loss = np.sum(losses)/Xd.shape[0]
        print("Epoch {2}, Overall loss = {0:.3g} and accuracy of {1:.3g}"\
              .format(total_loss,total_correct,e+1))
        
        feed_dict2 = {X: Xval,y: yval,is_training: False }
        loss2, corr2, _ = session.run([mean_loss,correct_prediction,accuracy],feed_dict=feed_dict2)
        temp2 = np.sum(corr2)/yval.shape[0]
        corrs2.append(temp2)
        print("Epoch {1},Valset accuracy {0:.3g}".format(temp2,e+1))
    if plot_losses:
        plt.plot(corrs)
        plt.plot(corrs2)
        plt.grid(True)
        plt.title('Acc'.format(e+1))
        plt.xlabel('epoch')
        plt.ylabel('accuracy')
        plt.show()
    return total_loss,total_correct

with tf.Session() as sess:
    with tf.device("/cpu:0"): #"/cpu:0" or "/gpu:0" 
        sess.run(tf.global_variables_initializer())
        print('Training')
        run_model(sess,y_out,mean_loss,X_train,y_train,X_val,y_val,1,64,100,train_step,True)
        #print('Validation')
        #run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Training
# Iteration 0: with minibatch training loss = 25.8 and accuracy of 0.078
# Iteration 100: with minibatch training loss = 2.3 and accuracy of 0.094
# Iteration 200: with minibatch training loss = 2.31 and accuracy of 0.11
# Iteration 300: with minibatch training loss = 2.31 and accuracy of 0.078
# Iteration 400: with minibatch training loss = 2.31 and accuracy of 0.047
# Iteration 500: with minibatch training loss = 2.29 and accuracy of 0.19
# Iteration 600: with minibatch training loss = 2.3 and accuracy of 0.12
# Iteration 700: with minibatch training loss = 2.31 and accuracy of 0.047
# Epoch 1, Overall loss = 2.62 and accuracy of 0.0996
# Epoch 1,Valset accuracy 0.102

# %% [markdown]
# ## Training a specific model
#
# In this section, we're going to specify a model for you to construct. The goal here isn't to get good performance (that'll be next), but instead to get comfortable with understanding the TensorFlow documentation and configuring your own model.
#
# Using the code provided above as guidance, and using the following TensorFlow documentation, specify a model with the following architecture:
#
# * 7x7 Convolutional Layer with 32 filters and stride of 1
# * ReLU Activation Layer
# * Spatial Batch Normalization Layer (trainable parameters, with scale and centering)
# * 2x2 Max Pooling layer with a stride of 2
# * Affine layer with 1024 output units
# * ReLU Activation Layer
# * Affine layer from 1024 input units to 10 outputs

# %%
# clear old variables
tf.reset_default_graph()

# define our input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

# define model
'''
def complex_model1(X,y,is_training):
    # define our weights (e.g. init_two_layer_convnet)
    
    # setup variables
    alpha  = 1e-4
    regularizer = tf.contrib.layers.l2_regularizer(scale=alpha)
    Wconv1 = tf.get_variable("Wconv1", shape=[6, 6, 3, 64],regularizer=regularizer)
    bconv1 = tf.get_variable("bconv1", shape=[64])
    W1 = tf.get_variable("W1", shape=[3136, 1024],regularizer=regularizer)
    b1 = tf.get_variable("b1", shape=[1024])
    W2 = tf.get_variable("W2", shape=[1024, 10],regularizer=regularizer)
    b2 = tf.get_variable("b2", shape=[10])

    # define our graph (e.g. two_layer_convnet)
    a1 = tf.nn.conv2d(X, Wconv1, strides=[1,2,2,1], padding='VALID') + bconv1
    h1 = tf.nn.relu(a1)
    
    batch1 = tf.layers.batch_normalization(h1)
    

    pool1 = tf.layers.max_pooling2d(batch1,2,2)
    h1_flat = tf.reshape(pool1,[-1,3136])
    #h1_flat = tf.reshape(h1,[-1,5408])
    
    a2 =tf.matmul(h1_flat,W1) + b1
    batch2 = tf.layers.batch_normalization(a2)
    h2 = tf.nn.relu(batch2)
    dropout2 = tf.layers.dropout(inputs=h2, rate=0.25)
    y_out = tf.matmul(h2,W2) + b2
    
    
    return y_out

'''
def complex_model2(X,y,is_training):
    # define our weights (e.g. init_two_layer_convnet)
    
    # setup variables
    alpha  = 2e-2
    regularizer=None
    regularizer = tf.contrib.layers.l2_regularizer(scale=alpha)
    Wconv1 = tf.get_variable("Wconv1", shape=[5, 5, 3, 64],regularizer=regularizer)
    bconv1 = tf.get_variable("bconv1", shape=[64])
    
    Wconv2 = tf.get_variable("Wconv2", shape=[3, 3, 64, 48],regularizer=regularizer)
    bconv2 = tf.get_variable("bconv2", shape=[48])
    
    W1 = tf.get_variable("W1", shape=[1728, 1024],regularizer=regularizer)
    b1 = tf.get_variable("b1", shape=[1024])
    W2 = tf.get_variable("W2", shape=[1024, 10],regularizer=regularizer)
    b2 = tf.get_variable("b2", shape=[10])

    # define our graph (e.g. two_layer_convnet)
    
    batch1 = tf.layers.batch_normalization(X)
    a1 = tf.nn.conv2d(batch1, Wconv1, strides=[1,1,1,1], padding='VALID') + bconv1
    h1 = tf.nn.relu(a1)
    pool1 = tf.layers.max_pooling2d(h1,2,2)
    batch2 = tf.layers.batch_normalization(pool1)
    a2 = tf.nn.conv2d(batch2, Wconv2, strides=[1,1,1,1], padding='VALID') + bconv2
    h2 = tf.nn.relu(a2)
    pool2 = tf.layers.max_pooling2d(h2,2,2)

    #pool1 = tf.layers.max_pooling2d(batch1,2,2)
    #h1_flat = tf.reshape(pool1,[-1,3136])
    h2_flat = tf.reshape(pool2,[-1,1728])
    
    a3 =tf.matmul(h2_flat,W1) + b1
    batch3 = tf.layers.batch_normalization(a3)
    h3 = tf.nn.relu(batch3)
    dropout3 = tf.layers.dropout(inputs=h3, rate=0.5)
    y_out = tf.matmul(h3,W2) + b2
    
    
    return y_out

y_out = complex_model2(X,y,is_training)

# %% [markdown]
# To make sure you're doing the right thing, use the following tool to check the dimensionality of your output (it should be 64 x 10, since our batches have size 64 and the output of the final affine layer should be 10, corresponding to our 10 classes):

# %%
# Now we're going to feed a random batch into the model 
# and make sure the output is the right size
x = np.random.randn(64, 32, 32,3)
with tf.Session() as sess:
    with tf.device("/cpu:0"): #"/cpu:0" or "/gpu:0"
        tf.global_variables_initializer().run()

        ans = sess.run(y_out,feed_dict={X:x,is_training:True})
        # %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
        print(ans.shape)
        print(np.array_equal(ans.shape, np.array([64, 10])))
# Out:
# 2.84 ms ± 42.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# (64, 10)
# True

# %% [markdown]
# You should see the following from the run above
#
# `(64, 10)`
#
# `True`

# %% [markdown]
# ### GPU!
#
# Now, we're going to try and start the model under the GPU device, the rest of the code stays unchanged and all our variables and operations will be computed using accelerated code paths. However, if there is no GPU, we get a Python exception and have to rebuild our graph. On a dual-core CPU, you might see around 50-80ms/batch running the above, while the Google Cloud GPUs (run below) should be around 2-5ms/batch.

# %% [markdown]
# try:
#     with tf.Session() as sess:
#         with tf.device("/gpu:0") as dev: #"/cpu:0" or "/gpu:0"
#             tf.global_variables_initializer().run()
#
#             ans = sess.run(y_out,feed_dict={X:x,is_training:True})
#             %timeit sess.run(y_out,feed_dict={X:x,is_training:True})
# except tf.errors.InvalidArgumentError:
#     print("no gpu found, please use Google Cloud if you want GPU acceleration")
#     # rebuild the graph
#     # trying to start a GPU throws an exception
#     # and also trashes the original graph
#     tf.reset_default_graph()
#     X = tf.placeholder(tf.float32, [None, 32, 32, 3])
#     y = tf.placeholder(tf.int64, [None])
#     is_training = tf.placeholder(tf.bool)
#     y_out = complex_model(X,y,is_training)

# %% [markdown]
# You should observe that even a simple forward pass like this is significantly faster on the GPU. So for the rest of the assignment (and when you go train your models in assignment 3 and your project!), you should use GPU devices. However, with TensorFlow, the default device is a GPU if one is available, and a CPU otherwise, so we can skip the device specification from now on.

# %% [markdown]
# ### Train the model.
#
# Now that you've seen how to define a model and do a single forward pass of some data through it, let's  walk through how you'd actually train one whole epoch over your training data (using the complex_model you created provided above).
#
# Make sure you understand how each TensorFlow function used below corresponds to what you implemented in your custom neural network implementation.
#
# First, set up an **RMSprop optimizer** (using a 1e-3 learning rate) and a **cross-entropy loss** function. See the TensorFlow documentation for more information
# * Layers, Activations, Loss functions : https://www.tensorflow.org/api_guides/python/nn
# * Optimizers: https://www.tensorflow.org/api_guides/python/train#Optimizers

# %%
# Inputs
#     y_out: is what your model computes
#     y: is your TensorFlow variable with label information
# Outputs
#    mean_loss: a TensorFlow variable (scalar) with numerical loss
#    optimizer: a TensorFlow optimizer
# This should be ~3 lines of code!
total_loss = tf.losses.softmax_cross_entropy(tf.one_hot(y,10),logits=y_out)
mean_loss = tf.reduce_mean(total_loss)+tf.losses.get_regularization_loss()
#mean_loss = tf.reduce_mean(total_loss)
#optimizer = tf.train.RMSPropOptimizer(1e-3) # select optimizer and set learning rate
global_step = tf.Variable(0, trainable=False)
starter_learning_rate = 5e-4
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
                                           1000, 0.7, staircase=True)

optimizer = tf.train.AdamOptimizer(learning_rate) # select optimizer and set learning rate

# %%
# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %% [markdown]
# ### Train the model
# Below we'll create a session and train the model over one epoch. You should see a loss of 1.4 to 2.0 and an accuracy of 0.4 to 0.5. There will be some variation due to random seeds and differences in initialization

# %%
sess = tf.Session()

sess.run(tf.global_variables_initializer())
print('Training')
run_model(sess,y_out,mean_loss,X_train,y_train,X_val,y_val,40,64,100,train_step,True)
# Out:
# Training
# Iteration 0: with minibatch training loss = 30.3 and accuracy of 0.2
# Iteration 100: with minibatch training loss = 12.3 and accuracy of 0.23
# Iteration 200: with minibatch training loss = 10.2 and accuracy of 0.34
# Iteration 300: with minibatch training loss = 8.64 and accuracy of 0.48
# Iteration 400: with minibatch training loss = 7.23 and accuracy of 0.48
# Iteration 500: with minibatch training loss = 6.78 and accuracy of 0.42
# Iteration 600: with minibatch training loss = 5.49 and accuracy of 0.52
# Iteration 700: with minibatch training loss = 5.1 and accuracy of 0.45
# Epoch 1, Overall loss = 8.71 and accuracy of 0.41
# Epoch 1,Valset accuracy 0.504
# Iteration 800: with minibatch training loss = 4.44 and accuracy of 0.53
# Iteration 900: with minibatch training loss = 4.18 and accuracy of 0.56
# Iteration 1000: with minibatch training loss = 3.78 and accuracy of 0.5
# Iteration 1100: with minibatch training loss = 3.22 and accuracy of 0.64
# Iteration 1200: with minibatch training loss = 3.11 and accuracy of 0.61
# Iteration 1300: with minibatch training loss = 2.99 and accuracy of 0.53
# Iteration 1400: with minibatch training loss = 2.19 and accuracy of 0.75
# Iteration 1500: with minibatch training loss = 2.53 and accuracy of 0.53
# Epoch 2, Overall loss = 3.38 and accuracy of 0.564
# Epoch 2,Valset accuracy 0.598
# Iteration 1600: with minibatch training loss = 2.39 and accuracy of 0.62
# Iteration 1700: with minibatch training loss = 2.48 and accuracy of 0.52
# Iteration 1800: with minibatch training loss = 2.52 and accuracy of 0.55
# Iteration 1900: with minibatch training loss = 2.52 and accuracy of 0.48
# Iteration 2000: with minibatch training loss = 1.9 and accuracy of 0.67
# Iteration 2100: with minibatch training loss = 1.88 and accuracy of 0.64
# Iteration 2200: with minibatch training loss = 1.84 and accuracy of 0.64
# Epoch 3, Overall loss = 2.04 and accuracy of 0.632
# Epoch 3,Valset accuracy 0.648
# Iteration 2300: with minibatch training loss = 1.57 and accuracy of 0.66
# Iteration 2400: with minibatch training loss = 1.97 and accuracy of 0.56
# Iteration 2500: with minibatch training loss = 1.58 and accuracy of 0.67
# Iteration 2600: with minibatch training loss = 1.6 and accuracy of 0.66
# Iteration 2700: with minibatch training loss = 1.57 and accuracy of 0.7
# Iteration 2800: with minibatch training loss = 1.37 and accuracy of 0.75
# Iteration 2900: with minibatch training loss = 1.69 and accuracy of 0.62
# Iteration 3000: with minibatch training loss = 1.51 and accuracy of 0.66
# Epoch 4, Overall loss = 1.57 and accuracy of 0.67
# Epoch 4,Valset accuracy 0.664
# Iteration 3100: with minibatch training loss = 1.75 and accuracy of 0.62
# Iteration 3200: with minibatch training loss = 1.39 and accuracy of 0.75
# Iteration 3300: with minibatch training loss = 1.34 and accuracy of 0.75
# Iteration 3400: with minibatch training loss = 1.3 and accuracy of 0.78
# Iteration 3500: with minibatch training loss = 1.25 and accuracy of 0.77
# Iteration 3600: with minibatch training loss = 1.25 and accuracy of 0.75
# Iteration 3700: with minibatch training loss = 1.34 and accuracy of 0.66
# Iteration 3800: with minibatch training loss = 1.43 and accuracy of 0.66
# Epoch 5, Overall loss = 1.36 and accuracy of 0.693
# Epoch 5,Valset accuracy 0.662
# Iteration 3900: with minibatch training loss = 1.32 and accuracy of 0.67
# Iteration 4000: with minibatch training loss = 1.12 and accuracy of 0.77
# Iteration 4100: with minibatch training loss = 1.28 and accuracy of 0.67
# Iteration 4200: with minibatch training loss = 0.997 and accuracy of 0.83
# Iteration 4300: with minibatch training loss = 1.19 and accuracy of 0.72
# Iteration 4400: with minibatch training loss = 1.42 and accuracy of 0.69
# Iteration 4500: with minibatch training loss = 1.08 and accuracy of 0.81
# Epoch 6, Overall loss = 1.25 and accuracy of 0.71
# Epoch 6,Valset accuracy 0.669
# Iteration 4600: with minibatch training loss = 0.939 and accuracy of 0.81
# Iteration 4700: with minibatch training loss = 1.24 and accuracy of 0.72
# Iteration 4800: with minibatch training loss = 0.99 and accuracy of 0.8
# Iteration 4900: with minibatch training loss = 1.16 and accuracy of 0.7
# Iteration 5000: with minibatch training loss = 1.41 and accuracy of 0.64
# Iteration 5100: with minibatch training loss = 1.12 and accuracy of 0.73
# Iteration 5200: with minibatch training loss = 1.1 and accuracy of 0.77
# Iteration 5300: with minibatch training loss = 1.22 and accuracy of 0.7
# Epoch 7, Overall loss = 1.19 and accuracy of 0.721
# Epoch 7,Valset accuracy 0.701
# Iteration 5400: with minibatch training loss = 1.14 and accuracy of 0.75
# Iteration 5500: with minibatch training loss = 1.28 and accuracy of 0.7
# Iteration 5600: with minibatch training loss = 1.16 and accuracy of 0.69
# Iteration 5700: with minibatch training loss = 1.08 and accuracy of 0.77
# Iteration 5800: with minibatch training loss = 0.961 and accuracy of 0.8
# Iteration 5900: with minibatch training loss = 1.45 and accuracy of 0.69
# Iteration 6000: with minibatch training loss = 1.12 and accuracy of 0.73
# Iteration 6100: with minibatch training loss = 1.33 and accuracy of 0.7
# Epoch 8, Overall loss = 1.14 and accuracy of 0.732
# Epoch 8,Valset accuracy 0.721
# Iteration 6200: with minibatch training loss = 0.947 and accuracy of 0.81
# Iteration 6300: with minibatch training loss = 1.21 and accuracy of 0.69
# Iteration 6400: with minibatch training loss = 0.983 and accuracy of 0.8
# Iteration 6500: with minibatch training loss = 0.867 and accuracy of 0.86
# Iteration 6600: with minibatch training loss = 1.07 and accuracy of 0.73
# Iteration 6700: with minibatch training loss = 0.98 and accuracy of 0.78
# Iteration 6800: with minibatch training loss = 1.2 and accuracy of 0.75
# Epoch 9, Overall loss = 1.1 and accuracy of 0.74
# Epoch 9,Valset accuracy 0.7
# Iteration 6900: with minibatch training loss = 0.853 and accuracy of 0.83
# Iteration 7000: with minibatch training loss = 0.819 and accuracy of 0.81
# Iteration 7100: with minibatch training loss = 1.06 and accuracy of 0.75
# Iteration 7200: with minibatch training loss = 1.04 and accuracy of 0.77
# Iteration 7300: with minibatch training loss = 1.06 and accuracy of 0.75
# Iteration 7400: with minibatch training loss = 0.961 and accuracy of 0.78
# Iteration 7500: with minibatch training loss = 1.08 and accuracy of 0.72
# Iteration 7600: with minibatch training loss = 1.06 and accuracy of 0.75
# Epoch 10, Overall loss = 1.07 and accuracy of 0.745
# Epoch 10,Valset accuracy 0.72
# Iteration 7700: with minibatch training loss = 0.963 and accuracy of 0.8
# Iteration 7800: with minibatch training loss = 0.909 and accuracy of 0.77
# Iteration 7900: with minibatch training loss = 1.15 and accuracy of 0.69
# Iteration 8000: with minibatch training loss = 1 and accuracy of 0.7
# Iteration 8100: with minibatch training loss = 1.23 and accuracy of 0.67
# Iteration 8200: with minibatch training loss = 1.07 and accuracy of 0.78
# Iteration 8300: with minibatch training loss = 1.12 and accuracy of 0.75
# Iteration 8400: with minibatch training loss = 1.06 and accuracy of 0.77
# Epoch 11, Overall loss = 1.04 and accuracy of 0.754
# Epoch 11,Valset accuracy 0.693
# Iteration 8500: with minibatch training loss = 0.963 and accuracy of 0.75
# Iteration 8600: with minibatch training loss = 0.926 and accuracy of 0.8
# Iteration 8700: with minibatch training loss = 0.873 and accuracy of 0.78
# Iteration 8800: with minibatch training loss = 1.17 and accuracy of 0.69
# Iteration 8900: with minibatch training loss = 0.997 and accuracy of 0.81
# Iteration 9000: with minibatch training loss = 1.05 and accuracy of 0.77
# Iteration 9100: with minibatch training loss = 0.824 and accuracy of 0.81
# Epoch 12, Overall loss = 1.03 and accuracy of 0.76
# Epoch 12,Valset accuracy 0.723
# Iteration 9200: with minibatch training loss = 0.92 and accuracy of 0.77
# Iteration 9300: with minibatch training loss = 0.833 and accuracy of 0.84
# Iteration 9400: with minibatch training loss = 1 and accuracy of 0.75
# Iteration 9500: with minibatch training loss = 0.731 and accuracy of 0.86
# Iteration 9600: with minibatch training loss = 0.899 and accuracy of 0.77
# Iteration 9700: with minibatch training loss = 0.917 and accuracy of 0.81
# Iteration 9800: with minibatch training loss = 0.995 and accuracy of 0.77
# Iteration 9900: with minibatch training loss = 1.18 and accuracy of 0.7
# Epoch 13, Overall loss = 1.01 and accuracy of 0.767
# Epoch 13,Valset accuracy 0.738
# Iteration 10000: with minibatch training loss = 1.01 and accuracy of 0.8
# Iteration 10100: with minibatch training loss = 0.892 and accuracy of 0.8
# Iteration 10200: with minibatch training loss = 0.944 and accuracy of 0.75
# Iteration 10300: with minibatch training loss = 0.858 and accuracy of 0.8
# Iteration 10400: with minibatch training loss = 0.907 and accuracy of 0.78
# Iteration 10500: with minibatch training loss = 0.995 and accuracy of 0.75
# Iteration 10600: with minibatch training loss = 0.761 and accuracy of 0.86
# Iteration 10700: with minibatch training loss = 0.932 and accuracy of 0.81
# Epoch 14, Overall loss = 0.992 and accuracy of 0.772
# Epoch 14,Valset accuracy 0.712
# Iteration 10800: with minibatch training loss = 0.963 and accuracy of 0.78
# Iteration 10900: with minibatch training loss = 1.13 and accuracy of 0.72
# Iteration 11000: with minibatch training loss = 0.891 and accuracy of 0.8
# Iteration 11100: with minibatch training loss = 1.14 and accuracy of 0.75
# Iteration 11200: with minibatch training loss = 1.13 and accuracy of 0.7
# Iteration 11300: with minibatch training loss = 0.807 and accuracy of 0.83
# Iteration 11400: with minibatch training loss = 0.857 and accuracy of 0.8
# Epoch 15, Overall loss = 0.987 and accuracy of 0.771
# Epoch 15,Valset accuracy 0.732
# Iteration 11500: with minibatch training loss = 0.968 and accuracy of 0.8
# Iteration 11600: with minibatch training loss = 1.04 and accuracy of 0.8
# Iteration 11700: with minibatch training loss = 1.06 and accuracy of 0.73
# Iteration 11800: with minibatch training loss = 0.791 and accuracy of 0.84
# Iteration 11900: with minibatch training loss = 1.15 and accuracy of 0.75
# Iteration 12000: with minibatch training loss = 1.08 and accuracy of 0.77
# Iteration 12100: with minibatch training loss = 0.996 and accuracy of 0.78
# Iteration 12200: with minibatch training loss = 0.93 and accuracy of 0.8
# Epoch 16, Overall loss = 0.969 and accuracy of 0.779
# Epoch 16,Valset accuracy 0.742
# Iteration 12300: with minibatch training loss = 0.757 and accuracy of 0.89
# Iteration 12400: with minibatch training loss = 0.893 and accuracy of 0.81
# Iteration 12500: with minibatch training loss = 0.911 and accuracy of 0.83
# Iteration 12600: with minibatch training loss = 0.767 and accuracy of 0.84
# Iteration 12700: with minibatch training loss = 1.07 and accuracy of 0.78
# Iteration 12800: with minibatch training loss = 0.893 and accuracy of 0.81
# Iteration 12900: with minibatch training loss = 1.16 and accuracy of 0.69
# Iteration 13000: with minibatch training loss = 0.945 and accuracy of 0.8
# Epoch 17, Overall loss = 0.957 and accuracy of 0.783
# Epoch 17,Valset accuracy 0.762
# Iteration 13100: with minibatch training loss = 0.69 and accuracy of 0.88
# Iteration 13200: with minibatch training loss = 1 and accuracy of 0.78
# Iteration 13300: with minibatch training loss = 1.12 and accuracy of 0.67
# Iteration 13400: with minibatch training loss = 1.14 and accuracy of 0.66
# Iteration 13500: with minibatch training loss = 1.09 and accuracy of 0.72
# Iteration 13600: with minibatch training loss = 1.01 and accuracy of 0.75
# Iteration 13700: with minibatch training loss = 0.94 and accuracy of 0.73
# Epoch 18, Overall loss = 0.948 and accuracy of 0.784
# Epoch 18,Valset accuracy 0.73
# Iteration 13800: with minibatch training loss = 0.827 and accuracy of 0.86
# Iteration 13900: with minibatch training loss = 0.828 and accuracy of 0.78
# Iteration 14000: with minibatch training loss = 0.862 and accuracy of 0.8
# Iteration 14100: with minibatch training loss = 0.857 and accuracy of 0.8
# Iteration 14200: with minibatch training loss = 0.913 and accuracy of 0.77
# Iteration 14300: with minibatch training loss = 1.07 and accuracy of 0.73
# Iteration 14400: with minibatch training loss = 0.91 and accuracy of 0.8
# Iteration 14500: with minibatch training loss = 1.01 and accuracy of 0.78
# Epoch 19, Overall loss = 0.939 and accuracy of 0.79
# Epoch 19,Valset accuracy 0.722
# Iteration 14600: with minibatch training loss = 0.786 and accuracy of 0.81
# Iteration 14700: with minibatch training loss = 0.787 and accuracy of 0.84
# Iteration 14800: with minibatch training loss = 0.851 and accuracy of 0.83
# Iteration 14900: with minibatch training loss = 0.872 and accuracy of 0.83
# Iteration 15000: with minibatch training loss = 0.888 and accuracy of 0.78
# Iteration 15100: with minibatch training loss = 0.917 and accuracy of 0.83
# Iteration 15200: with minibatch training loss = 0.935 and accuracy of 0.84
# Iteration 15300: with minibatch training loss = 1.12 and accuracy of 0.73
# Epoch 20, Overall loss = 0.929 and accuracy of 0.793
# Epoch 20,Valset accuracy 0.734
# Iteration 15400: with minibatch training loss = 0.847 and accuracy of 0.84
# Iteration 15500: with minibatch training loss = 0.786 and accuracy of 0.81
# Iteration 15600: with minibatch training loss = 1.02 and accuracy of 0.8
# Iteration 15700: with minibatch training loss = 0.868 and accuracy of 0.8
# Iteration 15800: with minibatch training loss = 0.935 and accuracy of 0.78
# Iteration 15900: with minibatch training loss = 1.07 and accuracy of 0.73
# Iteration 16000: with minibatch training loss = 0.783 and accuracy of 0.88
# Epoch 21, Overall loss = 0.922 and accuracy of 0.794
# Epoch 21,Valset accuracy 0.728
# Iteration 16100: with minibatch training loss = 0.746 and accuracy of 0.88
# Iteration 16200: with minibatch training loss = 0.922 and accuracy of 0.81
# Iteration 16300: with minibatch training loss = 0.825 and accuracy of 0.83
# Iteration 16400: with minibatch training loss = 1.01 and accuracy of 0.86
# Iteration 16500: with minibatch training loss = 1.08 and accuracy of 0.72
# Iteration 16600: with minibatch training loss = 0.923 and accuracy of 0.78
# Iteration 16700: with minibatch training loss = 0.828 and accuracy of 0.83
# Iteration 16800: with minibatch training loss = 1.05 and accuracy of 0.73
# Epoch 22, Overall loss = 0.916 and accuracy of 0.796
# Epoch 22,Valset accuracy 0.721
# Iteration 16900: with minibatch training loss = 0.651 and accuracy of 0.84
# Iteration 17000: with minibatch training loss = 0.785 and accuracy of 0.89
# Iteration 17100: with minibatch training loss = 0.879 and accuracy of 0.81
# Iteration 17200: with minibatch training loss = 1.03 and accuracy of 0.75
# Iteration 17300: with minibatch training loss = 1.22 and accuracy of 0.67
# Iteration 17400: with minibatch training loss = 0.975 and accuracy of 0.75
# Iteration 17500: with minibatch training loss = 1.18 and accuracy of 0.7
# Iteration 17600: with minibatch training loss = 0.967 and accuracy of 0.75
# Epoch 23, Overall loss = 0.914 and accuracy of 0.797
# Epoch 23,Valset accuracy 0.724
# Iteration 17700: with minibatch training loss = 1.1 and accuracy of 0.7
# Iteration 17800: with minibatch training loss = 0.855 and accuracy of 0.78
# Iteration 17900: with minibatch training loss = 0.932 and accuracy of 0.8
# Iteration 18000: with minibatch training loss = 0.776 and accuracy of 0.78
# Iteration 18100: with minibatch training loss = 0.947 and accuracy of 0.83
# Iteration 18200: with minibatch training loss = 1.11 and accuracy of 0.75
# Iteration 18300: with minibatch training loss = 0.897 and accuracy of 0.78
# Epoch 24, Overall loss = 0.903 and accuracy of 0.802
# Epoch 24,Valset accuracy 0.733
# Iteration 18400: with minibatch training loss = 0.834 and accuracy of 0.88
# Iteration 18500: with minibatch training loss = 1.06 and accuracy of 0.77
# Iteration 18600: with minibatch training loss = 0.803 and accuracy of 0.81
# Iteration 18700: with minibatch training loss = 1.08 and accuracy of 0.77
# Iteration 18800: with minibatch training loss = 0.747 and accuracy of 0.88
# Iteration 18900: with minibatch training loss = 0.757 and accuracy of 0.81
# Iteration 19000: with minibatch training loss = 1.01 and accuracy of 0.78
# Iteration 19100: with minibatch training loss = 0.926 and accuracy of 0.83
# Epoch 25, Overall loss = 0.905 and accuracy of 0.801
# Epoch 25,Valset accuracy 0.742
# Iteration 19200: with minibatch training loss = 0.722 and accuracy of 0.86
# Iteration 19300: with minibatch training loss = 1.02 and accuracy of 0.77
# Iteration 19400: with minibatch training loss = 0.77 and accuracy of 0.83
# Iteration 19500: with minibatch training loss = 1 and accuracy of 0.83
# Iteration 19600: with minibatch training loss = 0.918 and accuracy of 0.81
# Iteration 19700: with minibatch training loss = 0.844 and accuracy of 0.84
# Iteration 19800: with minibatch training loss = 0.936 and accuracy of 0.77
# Iteration 19900: with minibatch training loss = 1.14 and accuracy of 0.78
# Epoch 26, Overall loss = 0.893 and accuracy of 0.805
# Epoch 26,Valset accuracy 0.716
# Iteration 20000: with minibatch training loss = 0.806 and accuracy of 0.89
# Iteration 20100: with minibatch training loss = 0.697 and accuracy of 0.86
# Iteration 20200: with minibatch training loss = 0.833 and accuracy of 0.83
# Iteration 20300: with minibatch training loss = 1.26 and accuracy of 0.7
# Iteration 20400: with minibatch training loss = 0.882 and accuracy of 0.84
# Iteration 20500: with minibatch training loss = 1.22 and accuracy of 0.69
# Iteration 20600: with minibatch training loss = 0.922 and accuracy of 0.81
# Epoch 27, Overall loss = 0.889 and accuracy of 0.808
# Epoch 27,Valset accuracy 0.728
# Iteration 20700: with minibatch training loss = 0.885 and accuracy of 0.77
# Iteration 20800: with minibatch training loss = 0.766 and accuracy of 0.84
# Iteration 20900: with minibatch training loss = 0.787 and accuracy of 0.81
# Iteration 21000: with minibatch training loss = 1.21 and accuracy of 0.69
# Iteration 21100: with minibatch training loss = 0.855 and accuracy of 0.78
# Iteration 21200: with minibatch training loss = 0.91 and accuracy of 0.84
# Iteration 21300: with minibatch training loss = 1.04 and accuracy of 0.75
# Iteration 21400: with minibatch training loss = 0.799 and accuracy of 0.83
# Epoch 28, Overall loss = 0.882 and accuracy of 0.809
# Epoch 28,Valset accuracy 0.756
# Iteration 21500: with minibatch training loss = 0.726 and accuracy of 0.84
# Iteration 21600: with minibatch training loss = 0.587 and accuracy of 0.94
# Iteration 21700: with minibatch training loss = 0.841 and accuracy of 0.8
# Iteration 21800: with minibatch training loss = 0.846 and accuracy of 0.86
# Iteration 21900: with minibatch training loss = 0.858 and accuracy of 0.86
# Iteration 22000: with minibatch training loss = 0.789 and accuracy of 0.81
# Iteration 22100: with minibatch training loss = 0.855 and accuracy of 0.84
# Iteration 22200: with minibatch training loss = 0.973 and accuracy of 0.72
# Epoch 29, Overall loss = 0.879 and accuracy of 0.809
# Epoch 29,Valset accuracy 0.729
# Iteration 22300: with minibatch training loss = 0.607 and accuracy of 0.91
# Iteration 22400: with minibatch training loss = 0.694 and accuracy of 0.89
# Iteration 22500: with minibatch training loss = 0.921 and accuracy of 0.8
# Iteration 22600: with minibatch training loss = 1.09 and accuracy of 0.72
# Iteration 22700: with minibatch training loss = 1.04 and accuracy of 0.72
# Iteration 22800: with minibatch training loss = 0.831 and accuracy of 0.83
# Iteration 22900: with minibatch training loss = 0.905 and accuracy of 0.83
# Epoch 30, Overall loss = 0.877 and accuracy of 0.81
# Epoch 30,Valset accuracy 0.719
# Iteration 23000: with minibatch training loss = 0.872 and accuracy of 0.78
# Iteration 23100: with minibatch training loss = 0.707 and accuracy of 0.86
# Iteration 23200: with minibatch training loss = 0.87 and accuracy of 0.83
# Iteration 23300: with minibatch training loss = 0.937 and accuracy of 0.75
# Iteration 23400: with minibatch training loss = 0.789 and accuracy of 0.78
# Iteration 23500: with minibatch training loss = 0.761 and accuracy of 0.88
# Iteration 23600: with minibatch training loss = 0.818 and accuracy of 0.86
# Iteration 23700: with minibatch training loss = 0.702 and accuracy of 0.89
# Epoch 31, Overall loss = 0.88 and accuracy of 0.808
# Epoch 31,Valset accuracy 0.742
# Iteration 23800: with minibatch training loss = 0.623 and accuracy of 0.91
# Iteration 23900: with minibatch training loss = 0.869 and accuracy of 0.8
# Iteration 24000: with minibatch training loss = 1.16 and accuracy of 0.69
# Iteration 24100: with minibatch training loss = 0.962 and accuracy of 0.81
# Iteration 24200: with minibatch training loss = 0.941 and accuracy of 0.77
# Iteration 24300: with minibatch training loss = 0.715 and accuracy of 0.88
# Iteration 24400: with minibatch training loss = 0.972 and accuracy of 0.77
# Iteration 24500: with minibatch training loss = 0.984 and accuracy of 0.77
# Epoch 32, Overall loss = 0.876 and accuracy of 0.811
# Epoch 32,Valset accuracy 0.742
# Iteration 24600: with minibatch training loss = 0.729 and accuracy of 0.88
# Iteration 24700: with minibatch training loss = 0.769 and accuracy of 0.73
# Iteration 24800: with minibatch training loss = 0.756 and accuracy of 0.86
# Iteration 24900: with minibatch training loss = 0.861 and accuracy of 0.83
# Iteration 25000: with minibatch training loss = 0.817 and accuracy of 0.83
# Iteration 25100: with minibatch training loss = 0.781 and accuracy of 0.81
# Iteration 25200: with minibatch training loss = 0.865 and accuracy of 0.83
# Epoch 33, Overall loss = 0.864 and accuracy of 0.817
# Epoch 33,Valset accuracy 0.719
# Iteration 25300: with minibatch training loss = 0.702 and accuracy of 0.89
# Iteration 25400: with minibatch training loss = 0.696 and accuracy of 0.86
# Iteration 25500: with minibatch training loss = 0.816 and accuracy of 0.84
# Iteration 25600: with minibatch training loss = 0.829 and accuracy of 0.8
# Iteration 25700: with minibatch training loss = 0.802 and accuracy of 0.81
# Iteration 25800: with minibatch training loss = 0.845 and accuracy of 0.81
# Iteration 25900: with minibatch training loss = 0.86 and accuracy of 0.8
# Iteration 26000: with minibatch training loss = 1.14 and accuracy of 0.69
# Epoch 34, Overall loss = 0.859 and accuracy of 0.817
# Epoch 34,Valset accuracy 0.736
# Iteration 26100: with minibatch training loss = 0.856 and accuracy of 0.78
# Iteration 26200: with minibatch training loss = 0.793 and accuracy of 0.78
# Iteration 26300: with minibatch training loss = 0.79 and accuracy of 0.84
# Iteration 26400: with minibatch training loss = 1.02 and accuracy of 0.83
# Iteration 26500: with minibatch training loss = 0.899 and accuracy of 0.84
# Iteration 26600: with minibatch training loss = 0.906 and accuracy of 0.8
# Iteration 26700: with minibatch training loss = 0.919 and accuracy of 0.78
# Iteration 26800: with minibatch training loss = 0.644 and accuracy of 0.95
# Epoch 35, Overall loss = 0.864 and accuracy of 0.817
# Epoch 35,Valset accuracy 0.731
# Iteration 26900: with minibatch training loss = 0.921 and accuracy of 0.77
# Iteration 27000: with minibatch training loss = 1.03 and accuracy of 0.83
# Iteration 27100: with minibatch training loss = 0.99 and accuracy of 0.81
# Iteration 27200: with minibatch training loss = 0.784 and accuracy of 0.84
# Iteration 27300: with minibatch training loss = 1.07 and accuracy of 0.73
# Iteration 27400: with minibatch training loss = 0.768 and accuracy of 0.8
# Iteration 27500: with minibatch training loss = 1.06 and accuracy of 0.77
# Epoch 36, Overall loss = 0.863 and accuracy of 0.819
# Epoch 36,Valset accuracy 0.725
# Iteration 27600: with minibatch training loss = 0.704 and accuracy of 0.91
# Iteration 27700: with minibatch training loss = 0.917 and accuracy of 0.78
# Iteration 27800: with minibatch training loss = 0.902 and accuracy of 0.81
# Iteration 27900: with minibatch training loss = 0.777 and accuracy of 0.83
# Iteration 28000: with minibatch training loss = 0.889 and accuracy of 0.8
# Iteration 28100: with minibatch training loss = 0.94 and accuracy of 0.77
# Iteration 28200: with minibatch training loss = 0.795 and accuracy of 0.88
# Iteration 28300: with minibatch training loss = 0.771 and accuracy of 0.83
# Epoch 37, Overall loss = 0.864 and accuracy of 0.82
# Epoch 37,Valset accuracy 0.735
# Iteration 28400: with minibatch training loss = 0.824 and accuracy of 0.8
# Iteration 28500: with minibatch training loss = 0.876 and accuracy of 0.81
# Iteration 28600: with minibatch training loss = 0.677 and accuracy of 0.89
# Iteration 28700: with minibatch training loss = 0.814 and accuracy of 0.86
# Iteration 28800: with minibatch training loss = 0.996 and accuracy of 0.81
# Iteration 28900: with minibatch training loss = 0.891 and accuracy of 0.86
# Iteration 29000: with minibatch training loss = 1.01 and accuracy of 0.83
# Iteration 29100: with minibatch training loss = 0.965 and accuracy of 0.78
# Epoch 38, Overall loss = 0.853 and accuracy of 0.82
# Epoch 38,Valset accuracy 0.735
# Iteration 29200: with minibatch training loss = 0.756 and accuracy of 0.89
# Iteration 29300: with minibatch training loss = 0.983 and accuracy of 0.77
# Iteration 29400: with minibatch training loss = 0.8 and accuracy of 0.86
# Iteration 29500: with minibatch training loss = 1.05 and accuracy of 0.73
# Iteration 29600: with minibatch training loss = 0.886 and accuracy of 0.77
# Iteration 29700: with minibatch training loss = 0.742 and accuracy of 0.88
# Iteration 29800: with minibatch training loss = 0.891 and accuracy of 0.78
# Epoch 39, Overall loss = 0.856 and accuracy of 0.82
# Epoch 39,Valset accuracy 0.731
# Iteration 29900: with minibatch training loss = 0.801 and accuracy of 0.84
# Iteration 30000: with minibatch training loss = 0.74 and accuracy of 0.88
# Iteration 30100: with minibatch training loss = 0.807 and accuracy of 0.81
# Iteration 30200: with minibatch training loss = 0.711 and accuracy of 0.89
# Iteration 30300: with minibatch training loss = 0.74 and accuracy of 0.91
# Iteration 30400: with minibatch training loss = 0.869 and accuracy of 0.83
# Iteration 30500: with minibatch training loss = 0.97 and accuracy of 0.75
# Iteration 30600: with minibatch training loss = 0.683 and accuracy of 0.89
# Epoch 40, Overall loss = 0.851 and accuracy of 0.824
# Epoch 40,Valset accuracy 0.717
# (0.8506165589118491, 0.8240612244897959)

# %% [markdown]
# ### Check the accuracy of the model.
#
# Let's see the train and test code in action -- feel free to use these methods when evaluating the models you develop below. You should see a loss of 1.3 to 2.0 with an accuracy of 0.45 to 0.55.

# %%
print('Validation')
run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Validation
# Epoch 1, Overall loss = 3.53 and accuracy of 0.535
# [0.53500000000000003]
# (3.5250147838592527, 0.53500000000000003)

# %% [markdown]
# ## Train a _great_ model on CIFAR-10!
#
# Now it's your job to experiment with architectures, hyperparameters, loss functions, and optimizers to train a model that achieves ** >= 70% accuracy on the validation set** of CIFAR-10. You can use the `run_model` function from above.

# %% [markdown]
# ### Things you should try:
# - **Filter size**: Above we used 7x7; this makes pretty pictures but smaller filters may be more efficient
# - **Number of filters**: Above we used 32 filters. Do more or fewer do better?
# - **Pooling vs Strided Convolution**: Do you use max pooling or just stride convolutions?
# - **Batch normalization**: Try adding spatial batch normalization after convolution layers and vanilla batch normalization after affine layers. Do your networks train faster?
# - **Network architecture**: The network above has two layers of trainable parameters. Can you do better with a deep network? Good architectures to try include:
#     - [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [conv-relu-conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# - **Use TensorFlow Scope**: Use TensorFlow scope and/or [tf.layers](https://www.tensorflow.org/api_docs/python/tf/layers) to make it easier to write deeper networks. See [this tutorial](https://www.tensorflow.org/tutorials/layers) for how to use `tf.layers`.
# - **Use Learning Rate Decay**: [As the notes point out](http://cs231n.github.io/neural-networks-3/#anneal), decaying the learning rate might help the model converge. Feel free to decay every epoch, when loss doesn't change over an entire epoch, or any other heuristic you find appropriate. See the [Tensorflow documentation](https://www.tensorflow.org/versions/master/api_guides/python/train#Decaying_the_learning_rate) for learning rate decay.
# - **Global Average Pooling**: Instead of flattening and then having multiple affine layers, perform convolutions until your image gets small (7x7 or so) and then perform an average pooling operation to get to a 1x1 image picture (1, 1 , Filter#), which is then reshaped into a (Filter#) vector. This is used in [Google's Inception Network](https://arxiv.org/abs/1512.00567) (See Table 1 for their architecture).
# - **Regularization**: Add l2 weight regularization, or perhaps use [Dropout as in the TensorFlow MNIST tutorial](https://www.tensorflow.org/get_started/mnist/pros)
#
# ### Tips for training
# For each network architecture that you try, you should tune the learning rate and regularization strength. When doing this there are a couple important things to keep in mind:
#
# - If the parameters are working well, you should see improvement within a few hundred iterations
# - Remember the coarse-to-fine approach for hyperparameter tuning: start by testing a large range of hyperparameters for just a few training iterations to find the combinations of parameters that are working at all.
# - Once you have found some sets of parameters that seem to work, search more finely around these parameters. You may need to train for more epochs.
# - You should use the validation set for hyperparameter search, and we'll save the test set for evaluating your architecture on the best parameters as selected by the validation set.
#
# ### Going above and beyond
# If you are feeling adventurous there are many other features you can implement to try and improve your performance. You are **not required** to implement any of these; however they would be good things to try for extra credit.
#
# - Alternative update steps: For the assignment we implemented SGD+momentum, RMSprop, and Adam; you could try alternatives like AdaGrad or AdaDelta.
# - Alternative activation functions such as leaky ReLU, parametric ReLU, ELU, or MaxOut.
# - Model ensembles
# - Data augmentation
# - New Architectures
#   - [ResNets](https://arxiv.org/abs/1512.03385) where the input from the previous layer is added to the output.
#   - [DenseNets](https://arxiv.org/abs/1608.06993) where inputs into previous layers are concatenated together.
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)
#
# If you do decide to implement something extra, clearly describe it in the "Extra Credit Description" cell below.
#
# ### What we expect
# At the very least, you should be able to train a ConvNet that gets at **>= 70% accuracy on the validation set**. This is just a lower bound - if you are careful it should be possible to get accuracies much higher than that! Extra credit points will be awarded for particularly high-scoring models or unique approaches.
#
# You should use the space below to experiment and train your network. The final cell in this notebook should contain the training and validation set accuracies for your final trained network.
#
# Have fun and happy training!

# %%
# Feel free to play with this cell

def my_model(X,y,is_training):
    pass

tf.reset_default_graph()

X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

y_out = my_model(X,y,is_training)
mean_loss = None
optimizer = None


pass

# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %%
# Feel free to play with this cell
# This default code creates a session
# and trains your model for 10 epochs
# then prints the validation set accuracy
sess = tf.Session()

sess.run(tf.global_variables_initializer())
print('Training')
run_model(sess,y_out,mean_loss,X_train,y_train,10,64,100,train_step,True)
print('Validation')
run_model(sess,y_out,mean_loss,X_val,y_val,1,64)

# %%
# Test your model here, and make sure 
# the output of this cell is the accuracy
# of your best model on the training and val sets
# We're looking for >= 70% accuracy on Validation
print('Training')
run_model(sess,y_out,mean_loss,X_train,y_train,1,64)
print('Validation')
run_model(sess,y_out,mean_loss,X_val,y_val,1,64)

# %% [markdown]
# ### Describe what you did here
# In this cell you should also write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network

# %% [markdown]
# _Tell us here_

# %% [markdown]
# ### Test Set - Do this only once
# Now that we've gotten a result that we're happy with, we test our final model on the test set. This would be the score we would achieve on a competition. Think about how this compares to your validation set accuracy.

# %%
print('Test')
run_model(sess,y_out,mean_loss,X_test,y_test,1,64)
# Out:
# Test
# Epoch 1, Overall loss = 1.19 and accuracy of 0.717
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-d448826ac043> in <module>()
#       1 print('Test')
# ----> 2 run_model(sess,y_out,mean_loss,X_test,y_test,1,64)
#
# <ipython-input-41-cc2db233389f> in run_model(session, predict, loss_val, Xd, yd, Xval, yval, epochs, batch_size, print_every, training, plot_losses)
#      57
#      58         feed_dict2 = {X: Xval,y: yval,is_training: False }
# ---> 59         loss2, corr2, _ = session.run([mean_loss,correct_prediction,accuracy],feed_dict=feed_dict2)
#      60         temp2 = np.sum(corr2)/yval.shape[0]
#      61         corrs2.append(temp2)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1102                 'Cannot feed value of shape %r for Tensor %r, '
#    1103                 'which has shape %r'
# -> 1104                 % (np_val.shape, subfeed_t.name, str(subfeed_t.get_shape())))
#    1105           if not self.graph.is_feedable(subfeed_t):
#    1106             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape () for Tensor 'Placeholder:0', which has shape '(?, 32, 32, 3)'

# %% [markdown]
# ## Going further with TensorFlow
#
# The next assignment will make heavy use of TensorFlow. You might also find it useful for your projects.

# %% [markdown]
# # Extra Credit Description
# If you implement any additional features for extra credit, clearly describe them here with pointers to any code in this or other files if applicable.
